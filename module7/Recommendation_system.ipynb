# %% [markdown]
# <a href="https://colab.research.google.com/github/HalyshAnton/IT-Step-Pyton-AI/blob/main/module7/Recommendation_system.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

df = pd.read_csv("https://raw.githubusercontent.com/HalyshAnton/IT-Step-Pyton-AI/main/module7/data/fashion_products.csv")

df.head()
# Out:
#    User ID  Product ID Product Name   Brand         Category  Price    Rating  \
# 0       19           1        Dress  Adidas    Men's Fashion     40  1.043159
# 1       97           2        Shoes     H&M  Women's Fashion     82  4.026416
# 2       25           3        Dress  Adidas  Women's Fashion     44  3.337938
# 3       57           4        Shoes    Zara    Men's Fashion     23  1.049523
# 4       79           5      T-shirt  Adidas    Men's Fashion     79  4.302773
#
#     Color Size
# 0   Black   XL
# 1   Black    L
# 2  Yellow   XL
# 3   White    S
# 4   Black    M

# %%
df.describe()
# Out:
#           User ID   Product ID        Price       Rating
# count  1000.00000  1000.000000  1000.000000  1000.000000
# mean     50.41900   500.500000    55.785000     2.993135
# std      28.78131   288.819436    26.291748     1.153185
# min       1.00000     1.000000    10.000000     1.000967
# 25%      26.00000   250.750000    33.000000     1.992786
# 50%      50.00000   500.500000    57.000000     2.984003
# 75%      75.00000   750.250000    78.250000     3.985084
# max     100.00000  1000.000000   100.000000     4.987964

# %%
# !pip install -q surprise
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 772.0/772.0 kB 7.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#   Building wheel for scikit-surprise (setup.py) ... done

# %%
from surprise import Dataset, SVD, Reader

reader = Reader(rating_scale=(1, 5))

# The columns must correspond to user id, item id and ratings (in that order).
data = Dataset.load_from_df(df[["User ID", "Product ID", "Rating"]], reader)

data = data.build_full_trainset()

# %%
algo = SVD()
algo.fit(data)

# %%
algo.predict(200, -90000)
# Out:
# Prediction(uid=200, iid=-90000, r_ui=None, est=2.993135105762085, details={'was_impossible': False})

# %%
df[df['User ID'] == 2]
# Out:
#      User ID  Product ID Product Name   Brand         Category  Price  \
# 89         2          90        Jeans     H&M    Men's Fashion     37
# 152        2         153        Shoes    Nike    Kids' Fashion     31
# 551        2         552      Sweater  Adidas    Kids' Fashion     50
# 557        2         558        Jeans  Adidas  Women's Fashion     23
# 610        2         611        Shoes   Gucci    Kids' Fashion     85
# 673        2         674        Shoes  Adidas    Kids' Fashion     72
# 794        2         795        Jeans   Gucci    Kids' Fashion     30
# 849        2         850      T-shirt    Nike    Kids' Fashion     73
# 956        2         957        Jeans    Nike    Men's Fashion     57
#
#        Rating   Color Size
# 89   3.961592     Red   XL
# 152  1.946293   Black    S
# 551  4.480169    Blue    M
# 557  2.026682     Red   XL
# 610  2.032281   White    L
# 673  1.947338   Green    L
# 794  1.481967   Black    S
# 849  1.270583  Yellow    L
# 956  4.928869   White    L

# %%
# Out:
# Dataset ml-100k could not be found. Do you want to download it? [Y/n] y
# Trying to download dataset from https://files.grouplens.org/datasets/movielens/ml-100k.zip...
# Done! Dataset ml-100k has been saved to /root/.surprise_data/ml-100k
